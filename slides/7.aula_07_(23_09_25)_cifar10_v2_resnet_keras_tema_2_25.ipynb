# %% [markdown]
# <left><img src="https://i.ibb.co/zWjkHsWJ/marca-final-rgb-campanha-2025-versao02.png" width="35%" height="35%"></left>

# %% [markdown]
# # Tópicos em Matemática Aplicada: Deep Learning (Aula 07)
#
# Data: 23/set/25

# %%
import os
os.environ["KERAS_BACKEND"] = "torch"

# %%
import keras
import torch
from keras.datasets import cifar10
from keras.models import Sequential
from keras import datasets, layers, models
from keras.utils import to_categorical
from keras import regularizers
from keras.layers import Dense, Dropout, BatchNormalization
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns

# Checa a versão do keras e verifica se está de fato usando o Pytorch
print(f"Versão do Keras: {keras.__version__}")
print(f"Keras está usando o backend: {keras.backend.backend()}")
# Verifica se a GPU está disponível e define o dispositivo
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Usando o dispositivo: {device}")
# Out:
# Versão do Keras: 3.10.0
# Keras está usando o backend: torch
# Usando o dispositivo: cuda

# %%
# Use o backend PyTorch

from keras import layers, regularizers
from keras import optimizers
from keras import callbacks
from keras import losses, metrics

# Configurações
NUM_CLASSES = 10
BATCH_SIZE = 128
EPOCHS = 75
WEIGHT_DECAY = 1e-4
SEED = 42

keras.utils.set_random_seed(SEED)

# Dados: CIFAR-10 (numpy arrays, compatível com qualquer backend)
from keras.datasets import cifar10
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
y_train = y_train.squeeze().astype("int32")
y_test = y_test.squeeze().astype("int32")

# Bloco residual (BasicBlock) pós-ativação
def residual_block(x, filters, stride=1, weight_decay=1e-4):
    shortcut = x

    y = layers.Conv2D(
        filters, 3, strides=stride, padding="same",
        use_bias=False, kernel_initializer="he_normal",
        kernel_regularizer=regularizers.l2(weight_decay),
    )(x)
    y = layers.BatchNormalization(momentum=0.9, epsilon=1e-5)(y)
    y = layers.ReLU()(y)

    y = layers.Conv2D(
        filters, 3, strides=1, padding="same",
        use_bias=False, kernel_initializer="he_normal",
        kernel_regularizer=regularizers.l2(weight_decay),
    )(y)
    y = layers.BatchNormalization(momentum=0.9, epsilon=1e-5)(y)

    if stride != 1 or shortcut.shape[-1] != filters:
        shortcut = layers.Conv2D(
            filters, 1, strides=stride, padding="same",
            use_bias=False, kernel_initializer="he_normal",
            kernel_regularizer=regularizers.l2(weight_decay),
        )(shortcut)
        shortcut = layers.BatchNormalization(momentum=0.9, epsilon=1e-5)(shortcut)

    out = layers.Add()([y, shortcut])
    out = layers.ReLU()(out)
    return out

def build_resnet20(input_shape=(32, 32, 3), num_classes=10, weight_decay=1e-4):
    inputs = keras.Input(shape=input_shape)

    # Escala para [0,1]
    CIFAR10_MEAN = [0.4914, 0.4822, 0.4465]
    CIFAR10_STD = [0.2023, 0.1994, 0.2010]
    # A camada Normalization usa a VARIÂNCIA (desvio padrão ao quadrado)
    CIFAR10_VARIANCE = [std**2 for std in CIFAR10_STD]

    # Passo 1: Escala para [0,1]
    x = layers.Rescaling(1/255.0)(inputs)
    # Passo 2: Aplica a normalização de média e desvio padrão
    x = layers.Normalization(mean=CIFAR10_MEAN, variance=CIFAR10_VARIANCE)(x)

    # Data augmentation (apenas no treino)
    x = layers.ZeroPadding2D(4)(x)
    x = layers.RandomCrop(32, 32)(x)
    x = layers.RandomFlip("horizontal")(x)
    # x = layers.RandomRotation(0.1)(x)  # opcional

    # Conv inicial 3x3, 16 filtros
    x = layers.Conv2D(
        16, 3, strides=1, padding="same",
        use_bias=False, kernel_initializer="he_normal",
        kernel_regularizer=regularizers.l2(weight_decay),
    )(x)
    x = layers.BatchNormalization(momentum=0.9, epsilon=1e-5)(x)
    x = layers.ReLU()(x)

    # Estágio 1: 3 blocos 16 filtros
    x = residual_block(x, 16, stride=1, weight_decay=weight_decay)
    x = residual_block(x, 16, stride=1, weight_decay=weight_decay)
    x = residual_block(x, 16, stride=1, weight_decay=weight_decay)

    # Estágio 2: 3 blocos 32 filtros (downsample no primeiro)
    x = residual_block(x, 32, stride=2, weight_decay=weight_decay)
    x = residual_block(x, 32, stride=1, weight_decay=weight_decay)
    x = residual_block(x, 32, stride=1, weight_decay=weight_decay)

    # Estágio 3: 3 blocos 64 filtros (downsample no primeiro)
    x = residual_block(x, 64, stride=2, weight_decay=weight_decay)
    x = residual_block(x, 64, stride=1, weight_decay=weight_decay)
    x = residual_block(x, 64, stride=1, weight_decay=weight_decay)

    # Cabeça de classificação
    x = layers.GlobalAveragePooling2D()(x)
    outputs = layers.Dense(
        num_classes, activation="softmax",
        kernel_regularizer=regularizers.l2(weight_decay),
    )(x)

    model = keras.Model(inputs, outputs, name="ResNet20_CIFAR10")
    return model


model = build_resnet20(input_shape=(32, 32, 3), num_classes=NUM_CLASSES, weight_decay=WEIGHT_DECAY)
model.summary()

optimizer = optimizers.Adam(learning_rate=0.001)
loss = losses.SparseCategoricalCrossentropy()
metric_list = [metrics.SparseCategoricalAccuracy(name="acc")]

model.compile(optimizer=optimizer, loss=loss, metrics=metric_list)

# Lista de callbacks
cbs = [
    # Reduz o learning rate quando a val_loss não melhora por 3 épocas
    callbacks.ReduceLROnPlateau(
        monitor="val_loss", # Métrica a ser monitorada
        factor=0.2,         # Fator pelo qual o learning rate será reduzido (new_lr = lr * factor)
        patience=3,         # Número de épocas sem melhora para acionar a redução
        min_lr=1e-6,        # Limite inferior para o learning rate
        verbose=1           # Imprime uma mensagem quando o LR é atualizado
    ),
    # Salva o melhor modelo com base na menor val_loss
    callbacks.ModelCheckpoint(
        "resnet20_cifar10.weights.h5",
        monitor="val_loss",
        save_best_only=True,
        save_weights_only=True,
        mode="min", # "min" porque queremos minimizar a loss
    ),
    # Para o treinamento se a val_loss não melhorar por 10 épocas
    callbacks.EarlyStopping(
        monitor="val_loss",
        patience=10,
        restore_best_weights=True # Garante que o modelo final tenha os melhores pesos
    ),
]

# a função fit contendo o callback
history = model.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=1,
    shuffle=True,
    callbacks=cbs # Não se esqueça de passar os callbacks para o fit!
)

eval_loss, eval_acc = model.evaluate(x_test, y_test, verbose=0)
print(f"Acurácia no teste: {eval_acc:.4f}")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 13s 0us/step
# Model: "ResNet20_CIFAR10"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 32, 32, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 32, 32, 3) │          0 │ input_layer[0][0] │
# │ (Rescaling)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalization       │ (None, 32, 32, 3) │          0 │ rescaling[0][0]   │
# │ (Normalization)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d      │ (None, 40, 40, 3) │          0 │ normalization[0]… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ random_crop         │ (None, 32, 32, 3) │          0 │ zero_padding2d[0… │
# │ (RandomCrop)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ random_flip         │ (None, 32, 32, 3) │          0 │ random_crop[0][0] │
# │ (RandomFlip)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 32, 32,    │        432 │ random_flip[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 32, 32,    │         64 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 32, 32,    │      2,304 │ re_lu[0][0]       │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 32, 32,    │      2,304 │ re_lu_1[0][0]     │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ re_lu[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 32, 32,    │          0 │ add[0][0]         │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 32, 32,    │      2,304 │ re_lu_2[0][0]     │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 32,    │      2,304 │ re_lu_3[0][0]     │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ re_lu_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 32, 32,    │          0 │ add_1[0][0]       │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │      2,304 │ re_lu_4[0][0]     │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │      2,304 │ re_lu_5[0][0]     │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ re_lu_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 32, 32,    │          0 │ add_2[0][0]       │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 16, 16,    │      4,608 │ re_lu_6[0][0]     │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        128 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │      9,216 │ re_lu_7[0][0]     │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │        512 │ re_lu_6[0][0]     │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        128 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        128 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 16, 16,    │          0 │ add_3[0][0]       │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 16, 16,    │      9,216 │ re_lu_8[0][0]     │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        128 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 16, 16,    │      9,216 │ re_lu_9[0][0]     │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        128 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ re_lu_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 16, 16,    │          0 │ add_4[0][0]       │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 16, 16,    │      9,216 │ re_lu_10[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        128 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_11 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 16, 16,    │      9,216 │ re_lu_11[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        128 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ re_lu_10[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_12 (ReLU)     │ (None, 16, 16,    │          0 │ add_5[0][0]       │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 8, 8, 64)  │     18,432 │ re_lu_12[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_13 (ReLU)     │ (None, 8, 8, 64)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 8, 8, 64)  │     36,864 │ re_lu_13[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 8, 8, 64)  │      2,048 │ re_lu_12[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 8, 8, 64)  │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_14 (ReLU)     │ (None, 8, 8, 64)  │          0 │ add_6[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 8, 8, 64)  │     36,864 │ re_lu_14[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_15 (ReLU)     │ (None, 8, 8, 64)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 8, 8, 64)  │     36,864 │ re_lu_15[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 8, 8, 64)  │          0 │ batch_normalizat… │
# │                     │                   │            │ re_lu_14[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_16 (ReLU)     │ (None, 8, 8, 64)  │          0 │ add_7[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 8, 8, 64)  │     36,864 │ re_lu_16[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_17 (ReLU)     │ (None, 8, 8, 64)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 8, 8, 64)  │     36,864 │ re_lu_17[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 8, 8, 64)  │          0 │ batch_normalizat… │
# │                     │                   │            │ re_lu_16[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_18 (ReLU)     │ (None, 8, 8, 64)  │          0 │ add_8[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ re_lu_18[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 10)        │        650 │ global_average_p… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 274,042 (1.05 MB)
#  Trainable params: 272,474 (1.04 MB)
#  Non-trainable params: 1,568 (6.12 KB)
# Epoch 1/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 32s 75ms/step - acc: 0.3519 - loss: 1.9400 - val_acc: 0.4250 - val_loss: 1.8152 - learning_rate: 0.0010
# Epoch 2/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 74ms/step - acc: 0.5847 - loss: 1.3134 - val_acc: 0.5942 - val_loss: 1.3202 - learning_rate: 0.0010
# Epoch 3/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 73ms/step - acc: 0.6691 - loss: 1.0910 - val_acc: 0.6902 - val_loss: 1.0702 - learning_rate: 0.0010
# Epoch 4/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - acc: 0.7177 - loss: 0.9488 - val_acc: 0.6214 - val_loss: 1.2542 - learning_rate: 0.0010
# Epoch 5/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 74ms/step - acc: 0.7502 - loss: 0.8653 - val_acc: 0.6614 - val_loss: 1.0796 - learning_rate: 0.0010
# Epoch 6/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 73ms/step - acc: 0.7688 - loss: 0.8134 - val_acc: 0.7243 - val_loss: 0.9375 - learning_rate: 0.0010
# Epoch 7/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 73ms/step - acc: 0.7874 - loss: 0.7625 - val_acc: 0.7320 - val_loss: 0.9356 - learning_rate: 0.0010
# Epoch 8/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 74ms/step - acc: 0.7944 - loss: 0.7293 - val_acc: 0.7194 - val_loss: 0.9549 - learning_rate: 0.0010
# Epoch 9/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 74ms/step - acc: 0.8097 - loss: 0.6871 - val_acc: 0.7408 - val_loss: 0.8850 - learning_rate: 0.0010
# Epoch 10/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 72ms/step - acc: 0.8181 - loss: 0.6694 - val_acc: 0.7938 - val_loss: 0.7670 - learning_rate: 0.0010
# Epoch 11/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 72ms/step - acc: 0.8304 - loss: 0.6363 - val_acc: 0.7564 - val_loss: 0.8770 - learning_rate: 0.0010
# Epoch 12/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 72ms/step - acc: 0.8356 - loss: 0.6216 - val_acc: 0.7691 - val_loss: 0.8479 - learning_rate: 0.0010
# Epoch 13/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - acc: 0.8451 - loss: 0.5994
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 73ms/step - acc: 0.8451 - loss: 0.5994 - val_acc: 0.7610 - val_loss: 0.8407 - learning_rate: 0.0010
# Epoch 14/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 74ms/step - acc: 0.8684 - loss: 0.5289 - val_acc: 0.8436 - val_loss: 0.6447 - learning_rate: 2.0000e-04
# Epoch 15/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 73ms/step - acc: 0.8816 - loss: 0.4889 - val_acc: 0.8491 - val_loss: 0.6188 - learning_rate: 2.0000e-04
# Epoch 16/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - acc: 0.8850 - loss: 0.4798 - val_acc: 0.8553 - val_loss: 0.5985 - learning_rate: 2.0000e-04
# Epoch 17/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - acc: 0.8883 - loss: 0.4640 - val_acc: 0.8503 - val_loss: 0.6087 - learning_rate: 2.0000e-04
# Epoch 18/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 74ms/step - acc: 0.8894 - loss: 0.4589 - val_acc: 0.8636 - val_loss: 0.5869 - learning_rate: 2.0000e-04
# Epoch 19/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - acc: 0.8940 - loss: 0.4481 - val_acc: 0.8537 - val_loss: 0.5942 - learning_rate: 2.0000e-04
# Epoch 20/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 73ms/step - acc: 0.8915 - loss: 0.4461 - val_acc: 0.8529 - val_loss: 0.5913 - learning_rate: 2.0000e-04
# Epoch 21/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 73ms/step - acc: 0.8979 - loss: 0.4259 - val_acc: 0.8583 - val_loss: 0.5691 - learning_rate: 2.0000e-04
# Epoch 22/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 74ms/step - acc: 0.9006 - loss: 0.4208 - val_acc: 0.8572 - val_loss: 0.5677 - learning_rate: 2.0000e-04
# Epoch 23/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - acc: 0.9012 - loss: 0.4164 - val_acc: 0.8528 - val_loss: 0.5867 - learning_rate: 2.0000e-04
# Epoch 24/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 73ms/step - acc: 0.9044 - loss: 0.4119 - val_acc: 0.8566 - val_loss: 0.5723 - learning_rate: 2.0000e-04
# Epoch 25/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - acc: 0.9024 - loss: 0.4120 - val_acc: 0.8586 - val_loss: 0.5589 - learning_rate: 2.0000e-04
# Epoch 26/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 74ms/step - acc: 0.9050 - loss: 0.4029 - val_acc: 0.8561 - val_loss: 0.5610 - learning_rate: 2.0000e-04
# Epoch 27/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 74ms/step - acc: 0.9044 - loss: 0.4019 - val_acc: 0.8584 - val_loss: 0.5560 - learning_rate: 2.0000e-04
# Epoch 28/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - acc: 0.9092 - loss: 0.3909 - val_acc: 0.8535 - val_loss: 0.5695 - learning_rate: 2.0000e-04
# Epoch 29/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 74ms/step - acc: 0.9109 - loss: 0.3848 - val_acc: 0.8655 - val_loss: 0.5442 - learning_rate: 2.0000e-04
# Epoch 30/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 73ms/step - acc: 0.9146 - loss: 0.3746 - val_acc: 0.8617 - val_loss: 0.5483 - learning_rate: 2.0000e-04
# Epoch 31/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 73ms/step - acc: 0.9137 - loss: 0.3746 - val_acc: 0.8606 - val_loss: 0.5480 - learning_rate: 2.0000e-04
# Epoch 32/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - acc: 0.9118 - loss: 0.3771 - val_acc: 0.8665 - val_loss: 0.5290 - learning_rate: 2.0000e-04
# Epoch 33/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 72ms/step - acc: 0.9143 - loss: 0.3698 - val_acc: 0.8654 - val_loss: 0.5340 - learning_rate: 2.0000e-04
# Epoch 34/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - acc: 0.9171 - loss: 0.3640 - val_acc: 0.8700 - val_loss: 0.5225 - learning_rate: 2.0000e-04
# Epoch 35/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 74ms/step - acc: 0.9184 - loss: 0.3569 - val_acc: 0.8673 - val_loss: 0.5238 - learning_rate: 2.0000e-04
# Epoch 36/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 74ms/step - acc: 0.9196 - loss: 0.3520 - val_acc: 0.8675 - val_loss: 0.5212 - learning_rate: 2.0000e-04
# Epoch 37/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 74ms/step - acc: 0.9181 - loss: 0.3529 - val_acc: 0.8679 - val_loss: 0.5159 - learning_rate: 2.0000e-04
# Epoch 38/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 73ms/step - acc: 0.9229 - loss: 0.3462 - val_acc: 0.8629 - val_loss: 0.5395 - learning_rate: 2.0000e-04
# Epoch 39/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - acc: 0.9260 - loss: 0.3348 - val_acc: 0.8699 - val_loss: 0.5171 - learning_rate: 2.0000e-04
# Epoch 40/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - acc: 0.9228 - loss: 0.3421
# Epoch 40: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - acc: 0.9228 - loss: 0.3421 - val_acc: 0.8665 - val_loss: 0.5199 - learning_rate: 2.0000e-04
# Epoch 41/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 74ms/step - acc: 0.9315 - loss: 0.3194 - val_acc: 0.8738 - val_loss: 0.5016 - learning_rate: 4.0000e-05
# Epoch 42/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 73ms/step - acc: 0.9351 - loss: 0.3073 - val_acc: 0.8760 - val_loss: 0.5016 - learning_rate: 4.0000e-05
# Epoch 43/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 74ms/step - acc: 0.9374 - loss: 0.3025 - val_acc: 0.8766 - val_loss: 0.5023 - learning_rate: 4.0000e-05
# Epoch 44/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 74ms/step - acc: 0.9394 - loss: 0.2994 - val_acc: 0.8751 - val_loss: 0.5013 - learning_rate: 4.0000e-05
# Epoch 45/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 74ms/step - acc: 0.9382 - loss: 0.2981 - val_acc: 0.8765 - val_loss: 0.5009 - learning_rate: 4.0000e-05
# Epoch 46/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - acc: 0.9379 - loss: 0.2984 - val_acc: 0.8762 - val_loss: 0.4992 - learning_rate: 4.0000e-05
# Epoch 47/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - acc: 0.9393 - loss: 0.2964 - val_acc: 0.8753 - val_loss: 0.4961 - learning_rate: 4.0000e-05
# Epoch 48/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - acc: 0.9408 - loss: 0.2941 - val_acc: 0.8774 - val_loss: 0.4923 - learning_rate: 4.0000e-05
# Epoch 49/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - acc: 0.9413 - loss: 0.2925 - val_acc: 0.8758 - val_loss: 0.4966 - learning_rate: 4.0000e-05
# Epoch 50/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - acc: 0.9381 - loss: 0.2968 - val_acc: 0.8762 - val_loss: 0.4961 - learning_rate: 4.0000e-05
# Epoch 51/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - acc: 0.9413 - loss: 0.2880
# Epoch 51: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - acc: 0.9413 - loss: 0.2880 - val_acc: 0.8767 - val_loss: 0.4930 - learning_rate: 4.0000e-05
# Epoch 52/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - acc: 0.9450 - loss: 0.2809 - val_acc: 0.8780 - val_loss: 0.4923 - learning_rate: 8.0000e-06
# Epoch 53/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - acc: 0.9445 - loss: 0.2827 - val_acc: 0.8787 - val_loss: 0.4901 - learning_rate: 8.0000e-06
# Epoch 54/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 73ms/step - acc: 0.9427 - loss: 0.2804 - val_acc: 0.8774 - val_loss: 0.4934 - learning_rate: 8.0000e-06
# Epoch 55/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - acc: 0.9431 - loss: 0.2846 - val_acc: 0.8773 - val_loss: 0.4910 - learning_rate: 8.0000e-06
# Epoch 56/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - acc: 0.9430 - loss: 0.2840
# Epoch 56: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 74ms/step - acc: 0.9430 - loss: 0.2840 - val_acc: 0.8744 - val_loss: 0.5000 - learning_rate: 8.0000e-06
# Epoch 57/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - acc: 0.9444 - loss: 0.2818 - val_acc: 0.8768 - val_loss: 0.4937 - learning_rate: 1.6000e-06
# Epoch 58/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - acc: 0.9450 - loss: 0.2823 - val_acc: 0.8779 - val_loss: 0.4922 - learning_rate: 1.6000e-06
# Epoch 59/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - acc: 0.9429 - loss: 0.2860
# Epoch 59: ReduceLROnPlateau reducing learning rate to 1e-06.
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 73ms/step - acc: 0.9429 - loss: 0.2860 - val_acc: 0.8785 - val_loss: 0.4919 - learning_rate: 1.6000e-06
# Epoch 60/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - acc: 0.9454 - loss: 0.2785 - val_acc: 0.8779 - val_loss: 0.4902 - learning_rate: 1.0000e-06
# Epoch 61/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 73ms/step - acc: 0.9449 - loss: 0.2775 - val_acc: 0.8779 - val_loss: 0.4913 - learning_rate: 1.0000e-06
# Epoch 62/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 73ms/step - acc: 0.9407 - loss: 0.2879 - val_acc: 0.8772 - val_loss: 0.4906 - learning_rate: 1.0000e-06
# Epoch 63/75
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - acc: 0.9452 - loss: 0.2777 - val_acc: 0.8762 - val_loss: 0.4947 - learning_rate: 1.0000e-06
# Acurácia no teste: 0.8788
